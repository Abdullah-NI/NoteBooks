# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-NI/NoteBooks/blob/main/04_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##>Pandas library:
# >useful for data processing
#
# #>pandas data frame:
# >pandas data frame is two dimensional tabular data structure with labeled axes(rows and colum)

# %%
#importing the data library
import pandas as pd  #  ab ham every code me pandas ko pd likhege

# %% [markdown]
# Creating a pandas DataFrame

# %% [markdown]
# Importing data from a csv(coma seprated value) file to a pandas dataFrame

# %%
#csv file to pandas df
diabetes_df=pd.read_csv('/content/drive/MyDrive/AllDataset/diabetes.csv')  #path of diabetes.csv file

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()  #print first 5 rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loding the data from a exel file to a pandas DataFrame:
#
# pd.read_excel('file path')

# %%
diabetes_dfex=pd.read_excel('/content/drive/MyDrive/AllDataset/04 Book1.xlsx')

# %%
diabetes_dfex.head()
# Out:
# Empty DataFrame
# Columns: [name, age, gender, class]
# Index: []

# %% [markdown]
# Exporting a dataframe to a csv file

# %%
diabetes_df.to_csv('diabetes2.csv')
print(" ab file me diabetes2 name ki ek csv file ban gai")
# Out:
#  ab file me diabetes2 name ki ek csv file ban gai

# %% [markdown]
# exporting the pandas dataframe to an exel file:
#
# df.to_excel(file name)

# %%
diabetes_df.to_excel('diabetes3 excel.xlsx')
print(" ab file me diabetes3 excel name ki ek excel file ban gai")
# Out:
#  ab file me diabetes3 excel name ki ek excel file ban gai

# %% [markdown]
# Creating dataframe with random values

# %%
#creating a dataframe eith random value  so fist import numpy library
import numpy as np
random_df=pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.213032  0.301166  0.430477  0.464335  0.998151  0.005285  0.832450
# 1  0.153653  0.374265  0.716175  0.874859  0.500854  0.961050  0.090935
# 2  0.609297  0.195376  0.363588  0.371201  0.232439  0.837291  0.315691
# 3  0.918999  0.818981  0.398015  0.500781  0.991445  0.148532  0.332925
# 4  0.719286  0.726032  0.869492  0.151087  0.789340  0.151530  0.171260
#
#           7         8         9
# 0  0.399681  0.017928  0.800056
# 1  0.422575  0.975947  0.356560
# 2  0.736067  0.671973  0.398840
# 3  0.225039  0.319897  0.391632
# 4  0.409973  0.853125  0.280243

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# #**Inspecting a data frame**

# %%
#finding no of rows and no of column
diabetes_df.shape
# Out:
# (768, 9)

# %%
#first five rose of a dataframe
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#last 5 rows of data frame
diabetes_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#information about data frame
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on the lables (means column ke name ke according)
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
diabetes_df.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 52     8
# 44     8
# 50     8
# 51     8
# 58     7
# 54     6
# 47     6
# 53     5
# 60     5
# 49     5
# 57     5
# 48     5
# 66     4
# 62     4
# 63     4
# 55     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# Name: count, dtype: int64

# %%
#group the value based on mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# #**Statical Measures**

# %%
#count or number of values in each column
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean values column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#standard devoation column wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#varience   standard devation=under root of vari#enece
diabetes_df.var()
# Out:
# Pregnancies                    11.354056
# Glucose                      1022.248314
# BloodPressure                 374.647271
# SkinThickness                 254.473245
# Insulin                     13281.180078
# BMI                            62.159984
# DiabetesPedigreeFunction        0.109779
# Age                           138.303046
# Outcome                         0.227483
# dtype: float64

# %%
#minimum values
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#max value
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
#all the statical measure about the dataframe
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# #**Manipulating a DataFrame**

# %%
#adding a column to a dataframe
diabetes_df['price']=np.random.randint(10,50,size=len(diabetes_df))

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  price
# 0                     0.627   50        1     45
# 1                     0.351   31        0     41
# 2                     0.672   32        1     33
# 3                     0.167   21        0     42
# 4                     2.288   33        1     39

# %%
diabetes_df.price.count()
# Out:
# 768

# %%
#removing a row
diabetes_df.drop(index=0,axis=0)  #axis=0 for row axis=1 for column
                                  # here i remove temparary if we want permanently then store it in a varibale like this
                                  #diabetes_df=diabetes_df.drop(index=0,axis=0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  price
# 1                       0.351   31        0     41
# ...

# %%
#drop a column
diabetes_df.drop(columns='Age',axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome  price
# 0                       0.627        1     45
# ...

# %%
#locating a row usig index value
diabetes_df.iloc[2]
#print(diabetes_df.iloc[2])
# Out:
# Pregnancies                   8.000
# Glucose                     183.000
# BloodPressure                64.000
# SkinThickness                 0.000
# Insulin                       0.000
# BMI                          23.300
# DiabetesPedigreeFunction      0.672
# Age                          32.000
# Outcome                       1.000
# price                        33.000
# Name: 2, dtype: float64

# %%
#locating a particular column
print(diabetes_df.iloc[:,0])  #FIRST COLUMN
print(diabetes_df.iloc[:,1])  #2nd c0lumn
print(diabetes_df.iloc[:,2])
print(diabetes_df.iloc[:,-1]) #  last col bcz -ve indexing
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64
# 0      45
# 1      41
# 2      33
# 3      42
# 4      39
#        ..
# 763    32
# 764    37
# 765    42
# 766    34
# 767    19
# Name: price, Length: 768, dtype: int64

# %%
print(diabetes_df.iloc[1,2])  # printing value of 1st row and 2nd col
# Out:
# 66

# %% [markdown]
# #**Corelation**:
# 1. positive correlation(means if one thing is increase or dec then other thing also inc. or dec)
# 2. negative correlation(if one thing is dec. the other is inc.)

# %%
diabetes_df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
# price                       -0.080262 -0.014697       0.025407       0.010319
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# ...
